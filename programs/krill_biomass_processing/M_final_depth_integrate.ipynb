# %%
import final_depth_integrate
from final_depth_integrate import final_depth_integrate
import os.path

fname_beg = '../../input_data/acoustic_reprocessing/JRS_2014_reprocessed/2014'
fname_inend = '_reprocessed.csv'
fname_end = '../../output_data/acoustic_reprocessing/JRS_2014_reprocessed_output/2014'
fname_outend = '_reprocessed_depth_integrated.csv'

#2012flist=['0507a', '0507b', '0508a', '0508b', '0509a', '0509b', '0510a', '0510b',
#       '0511a', '0511b', '0512a', '0512b', '0513a', '0513b', '0514a', '0514b',  
#       '0515a', '0515b', '0516a', '0516b', '0517a', '0517b', '0518a', '0518b', 
#       '0521a', '0522a', '0522b', '0523', '0524', '0525', '0526',
#       '0527', '0528', '0529', '0530', '0531','0601', '0602', '0603', 
#       '0610', '0612', '0613', '0614', '0615', '0616'] 
#2013flist=['0509', '0510', '0511a', '0511b', '0512', '0513', '0514',
#       '0516', '0517', '0518', '0519', '0520',  '0521', '0522', '0523', '0524',
#       '0525', '0526', '0527', '0528', '0529', '0601', '0602', '0603', '0604',
#       '0605', '0606', '0607', '0608', '0609', '0610', '0611', '0612', '0613', 
#       '0614', '0615', '0616', '0617a', '0617b', '0617c', '0617d', '0618a', 
#       '0618b', '0618c', '0618d', '0619a', '0619b', '0620'] 

flist=['0502_03', '0504', '0505', '0506', '0507', '0508', '0509', 
       '0510', '0511', '0512', '0513', '0514', '0515', '0516', '0517', '0518', '0519', 
       '0520', '0521', '0522', '0523', '0524', '0527_28', '0529', '0530', '0531', 
       '0601', '0602', '0603', '0604', '0605', '0606', '0607', '0608', '0609', 
       '0610', '0611', '0612', '0613', '0614', '0615_16'] 



for i in flist:
    fin=fname_beg+i+fname_inend
    fout=fname_end+i+fname_outend
    final_depth_integrate(fin,fout)

#fin=fname_beg+'0509a'+fname_inend
#fout=fname_beg+'0507a'+fname_outend
#os.path.isfile(str(fin))
#final_depth_integrate(fin,fout)
#print (fin)
# Out:
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140502_03_reprocessed_depth_integrated.csv with 595 rows.
# Processing took 5.564435005187988 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140504_reprocessed_depth_integrated.csv with 542 rows.
# Processing took 4.9863200187683105 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140505_reprocessed_depth_integrated.csv with 512 rows.
# Processing took 4.6492674350738525 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140506_reprocessed_depth_integrated.csv with 503 rows.
# Processing took 4.573286056518555 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140507_reprocessed_depth_integrated.csv with 511 rows.
# Processing took 4.661936044692993 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140508_reprocessed_depth_integrated.csv with 547 rows.
# Processing took 4.974539041519165 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140509_reprocessed_depth_integrated.csv with 572 rows.
# Processing took 5.311154842376709 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140510_reprocessed_depth_integrated.csv with 787 rows.
# Processing took 9.113199234008789 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140511_reprocessed_depth_integrated.csv with 583 rows.
# Processing took 5.960448980331421 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140512_reprocessed_depth_integrated.csv with 550 rows.
# Processing took 5.214237928390503 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140513_reprocessed_depth_integrated.csv with 488 rows.
# Processing took 4.555876970291138 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140514_reprocessed_depth_integrated.csv with 590 rows.
# Processing took 5.436776876449585 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140515_reprocessed_depth_integrated.csv with 475 rows.
# Processing took 4.345931053161621 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140516_reprocessed_depth_integrated.csv with 426 rows.
# Processing took 3.8665428161621094 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140517_reprocessed_depth_integrated.csv with 428 rows.
# Processing took 3.904015064239502 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140518_reprocessed_depth_integrated.csv with 526 rows.
# Processing took 4.78399920463562 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140519_reprocessed_depth_integrated.csv with 489 rows.
# Processing took 4.41002893447876 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140520_reprocessed_depth_integrated.csv with 509 rows.
# Processing took 4.619919061660767 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140521_reprocessed_depth_integrated.csv with 515 rows.
# Processing took 4.603646993637085 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140522_reprocessed_depth_integrated.csv with 490 rows.
# Processing took 4.439975023269653 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140523_reprocessed_depth_integrated.csv with 505 rows.
# Processing took 4.645100116729736 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140524_reprocessed_depth_integrated.csv with 363 rows.
# Processing took 3.2655558586120605 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140527_28_reprocessed_depth_integrated.csv with 806 rows.
# Processing took 7.4602508544921875 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140529_reprocessed_depth_integrated.csv with 473 rows.
# Processing took 4.314192056655884 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140530_reprocessed_depth_integrated.csv with 587 rows.
# Processing took 5.518952131271362 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140531_reprocessed_depth_integrated.csv with 525 rows.
# Processing took 4.802464008331299 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140601_reprocessed_depth_integrated.csv with 520 rows.
# Processing took 4.774088144302368 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140602_reprocessed_depth_integrated.csv with 390 rows.
# Processing took 3.724943161010742 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140603_reprocessed_depth_integrated.csv with 463 rows.
# Processing took 4.31023907661438 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140604_reprocessed_depth_integrated.csv with 499 rows.
# Processing took 4.693272113800049 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140605_reprocessed_depth_integrated.csv with 455 rows.
# Processing took 4.1701741218566895 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140606_reprocessed_depth_integrated.csv with 581 rows.
# Processing took 5.390357971191406 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140607_reprocessed_depth_integrated.csv with 603 rows.
# Processing took 5.435367107391357 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140608_reprocessed_depth_integrated.csv with 508 rows.
# Processing took 4.639890909194946 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140609_reprocessed_depth_integrated.csv with 470 rows.
# Processing took 4.107136011123657 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140610_reprocessed_depth_integrated.csv with 424 rows.
# Processing took 3.80869197845459 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140611_reprocessed_depth_integrated.csv with 494 rows.
# Processing took 4.494721174240112 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140612_reprocessed_depth_integrated.csv with 450 rows.
# Processing took 4.347426891326904 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140613_reprocessed_depth_integrated.csv with 419 rows.
# Processing took 4.111081838607788 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140614_reprocessed_depth_integrated.csv with 435 rows.
# Processing took 4.139279127120972 seconds.
#
# Writing ../../data/acoustic_reprocessing/JRS_2014_reprocessed/JRS_2014_reprocessed_output/20140615_16_reprocessed_depth_integrated.csv with 725 rows.
# Processing took 7.041313171386719 seconds.
